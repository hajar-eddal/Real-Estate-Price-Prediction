# %% [markdown]
# <h1>Régression des prix du logement</h1>

# %% [markdown]
# <h3>Objectif</h3>
#
# prédire le prix de vente de chaque maison

# %%
#import packages 

import pandas as pd 
import numpy as np 
import plotly.graph_objects as go
import plotly.express as px
import scipy.stats as stats
from IPython.display import display, HTML

# %% [markdown]
# # Data Exploration

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# # create scrollable table within a small window

# %%
def create_scrollable_table(df ,table_id ,title):
    html = f'<h3>{title}</h3>'
    html += '<dive id="{table_id}" style="hight:300px ; overflow:auto;">'
    html += df.to_html()
    html += '</div>'
    return html

# %%
df.shape
# Out:
# (1460, 81)

# %%
numerical_features = df.select_dtypes(include=[np.number])
summary_stats = numerical_features.describe().T
html_numerical = create_scrollable_table(summary_stats, 'numerical_features', 'Summary statistics for numerical features')
display(HTML(html_numerical))
# Out:
# <h3>Summary statistics for numerical features</h3><dive id="{table_id}" style="hight:300px ; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Id</th>
#       <td>1460.0</td>
#       <td>730.500000</td>
#       <td>421.610009</td>
#       <td>1.0</td>
#       <td>365.75</td>
#       <td>730.5</td>
#       <td>1095.25</td>
#       <td>1460.0</td>
#     </tr>
#     <tr>
#       <th>MSSubClass</th>
#       <td>1460.0</td>
#       <td>56.897260</td>
#       <td>42.300571</td>
#       <td>20.0</td>
#       <td>20.00</td>
#       <td>50.0</td>
#       <td>70.00</td>
#       <td>190.0</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>1201.0</td>
#       <td>70.049958</td>
# ...

# %%
categorical_features = df.select_dtypes(include=([object]))
cat_summary_stats = categorical_features.describe().T
html_categorical = create_scrollable_table(cat_summary_stats , 'categorical_features','Summary statistics for categorical features\n')
display(HTML(html_categorical))
# Out:
# <h3>Summary statistics for categorical features
# </h3><dive id="{table_id}" style="hight:300px ; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MSZoning</th>
#       <td>1460</td>
#       <td>5</td>
#       <td>RL</td>
#       <td>1151</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>1460</td>
#       <td>2</td>
#       <td>Pave</td>
#       <td>1454</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>91</td>
#       <td>2</td>
#       <td>Grvl</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>1460</td>
#       <td>4</td>
#       <td>Reg</td>
#       <td>925</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>1460</td>
#       <td>4</td>
#       <td>Lvl</td>
#       <td>1311</td>
# ...

# %%
null_values = df.isnull().sum()
html_null_values =create_scrollable_table(null_values.to_frame() , 'html_null_values' , 'the null values in Dataset')
display(HTML(html_null_values))
# Out:
# <h3>the null values in Dataset</h3><dive id="{table_id}" style="hight:300px ; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>MSSubClass</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>MSZoning</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>259</td>
#     </tr>
#     <tr>
#       <th>LotArea</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>1369</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Utilities</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>LotConfig</th>
#       <td>0</td>
# ...

# %%
missing_percentage = (df.isnull().sum()/len(df))*100
html_missing_percentage = create_scrollable_table(missing_percentage.to_frame(),'html_missing_percentage','the percentage of missing values for each feature')

display(HTML(html_missing_percentage))
# Out:
# <h3>the percentage of missing values for each feature</h3><dive id="{table_id}" style="hight:300px ; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Id</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>MSSubClass</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>MSZoning</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>17.739726</td>
#     </tr>
#     <tr>
#       <th>LotArea</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>93.767123</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Utilities</th>
# ...

# %%
rows_with_missing_values = df[df.isnull().any(axis=1)]
html_rows_missing_values = create_scrollable_table(rows_with_missing_values.head(10),'html_rows_missing_values','the rows with missing values')
display(HTML(html_rows_missing_values))
# Out:
# <h3>the rows with missing values</h3><dive id="{table_id}" style="hight:300px ; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>Condition2</th>
#       <th>BldgType</th>
#       <th>HouseStyle</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#       <th>RoofStyle</th>
#       <th>RoofMatl</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>MasVnrType</th>
#       <th>MasVnrArea</th>
#       <th>ExterQual</th>
#       <th>ExterCond</th>
# ...

# %%
import scipy.stats as stats

# Fit a normal distribution to the SalePrice data
mu, sigma = stats.norm.fit(df['SalePrice'])

# Create a histogram of the SalePrice column
hist_data = go.Histogram(
    x=df['SalePrice'],
    nbinsx=50,
    name="Histogram",
    opacity=0.75,
    histnorm='probability density',
    marker=dict(color='#39A7FF')
)

# Calculate the normal distribution based on the fitted parameters
x_norm = np.linspace(df['SalePrice'].min(), df['SalePrice'].max(), 100)
y_norm = stats.norm.pdf(x_norm, mu, sigma)

# Create the normal distribution overlay
norm_data = go.Scatter(
    x=x_norm,
    y=y_norm,
    mode="lines",
    name=f"Normal dist. (μ={mu:.2f}, σ={sigma:.2f})",
    line=dict(color="#FFC436")
)

# %%
# Combine the histogram and the overlay
fig = go.Figure(data=[hist_data, norm_data])

# %%
# Set the layout for the plot
fig.update_layout(
    title="SalePrice Distribution",
    xaxis_title="SalePrice",
    yaxis_title="Density",
    legend_title_text="Fitted Normal Distribution",
    plot_bgcolor='#222831',
    paper_bgcolor='#222831',
    font=dict(color='#FFFFFF')
)

# %%
# Create a Q-Q plot
qq_data = stats.probplot(df['SalePrice'], dist="norm")
qq_fig = px.scatter(
    x=qq_data[0][0],
    y=qq_data[0][1],
    labels={'x': 'Theoretical Quantiles', 'y': 'Ordered Values'},
    color_discrete_sequence=["#39A7FF"]
)

# Set layout for the Q-Q plot
qq_fig.update_layout(
    title="Q-Q plot",
    plot_bgcolor='#222831',
    paper_bgcolor='#222831',
    font=dict(color='#FFFFFF')
)

# Calculate the line of best fit
slope, intercept, r_value, p_value, std_err = stats.linregress(qq_data[0][0] ,qq_data[0][1] )
line_x = np.array(qq_data[0][0])
line_y = intercept + slope*line_x

# Add the line of best fit to the Q-Q plot
line_data = go.Scatter(
     x=line_x,
     y=line_y,
     mode='lines',
     name='normal line',
     line=dict(color='#FFC436')     
)
qq_fig.add_trace(line_data)

# %% [markdown]
#  <h3>Questions we want to ask of the data:</h3><br>
# -How these variables affect the price of the house?<br>
# 1-Distribution<br>
# 2-Zoning <br>
# 3-Types of access to streets and alleys<br>
# 4-Age of the property<br>
# 5-Living space<br>
# -Does the price change year to year?<br>
# -What is the Average sale price by property shape?<br>

# %%
#1. Distribution of dwelling types and their relation to sale prices

# Get the count of each unique value in the 'BldgType' column
dwelling_types = df['BldgType'].value_counts()

# Group the DataFrame by 'BldgType' and calculate the mean of 'SalePrice' for each group
dwelling_prices = df.groupby('BldgType')['SalePrice'].mean()

# Format labels for the second graph as currency values
formatted_dwelling_prices = ['$' + f'{value:,.2f}' for value in dwelling_prices.values]

# Create a bar chart for the distribution of building types
fig1 = go.Figure(data=[go.Bar(
    x=dwelling_types.index,
    y=dwelling_types.values,
    marker_color='#39A7FF',  # Set color
    text=dwelling_types.values,
    textposition='outside',
    width=0.4,
    marker=dict(line=dict(width=2, color='#39A7FF'), opacity=1)  # Set line properties
)])

# Update the layout for figure1
fig1.update_layout(
    title='Distribution of Building Types',
    xaxis_title='Building Type',
    yaxis_title='Count',
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF')  
)

# Create a bar chart for the average sale prices by building type
fig2 = go.Figure(data=[go.Bar(
      x=dwelling_prices.index,
      y=dwelling_prices.values,
      marker_color='#FFC436',
      text=formatted_dwelling_prices,
      textposition='outside',
      width=0.4,
      marker=dict(line=dict(width=2, color='#FFC436'), opacity=1)

)])

# Update the layout for figure2
fig2.update_layout(
    title='Average Sale Price by Building Type',
    xaxis_title='Building Type',
    yaxis_title='Price',
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',
    font=dict(color='#FFFFFF')
)
  
# Show the figures
fig1.show()
fig2.show()

# %%
# 2. Zoning impact on sale price

zoning_prices = df.groupby('MSZoning')['SalePrice'].mean()

# Create a bar chart for the average sale prices by zoning using Plotly Express
fig3 = px.bar(
    x=zoning_prices.index,
    y=zoning_prices.values,
    title='Average Sale Price by Zoning',
    color_discrete_sequence=['#39A7FF', '#FFC436'],
    text=zoning_prices.values,
    template='plotly_dark'
)

# Update trace properties
fig3.update_traces(
    texttemplate='$%{text:,.0f}',
    textposition='outside') # Format text as currency and set its position

# Update layout
fig3.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF')  
)

fig3.update_xaxes(title='Zoning')

# Update y-axis properties
fig3.update_yaxes(title='Sale Price', tickprefix='$', tickformat=',')  # Set title, tick prefix, and format

fig3.show()

# %%
# 3. Street and alley access types effect on sale price

# Group the DataFrame by 'Street' and 'Alley' and calculate the mean of 'SalePrice' for each group
street_prices = df.groupby('Street')['SalePrice'].mean()
alley_prices = df.groupby('Alley')['SalePrice'].mean()

# Street Prices

# Assign colors based on the street type ('Pave' or 'Grvl')
colors_street = np.where(street_prices.index == 'Pave', '#FFC436', '#39A7FF')

# Create a bar chart for the average sale prices by street type
fig5 = px.bar(
    x=street_prices.index,  
    y=street_prices.values, 
    title='Average Sale Price by Street Type',  
    template='plotly_dark',  
    text=street_prices.values,  
    color=colors_street,  
    color_discrete_sequence=['#FFC436', '#39A7FF']  
)

# Format the text on the bars as currency values
fig5.update_traces(texttemplate='$%{text:,.0f}', textposition='outside')

# Customize the y-axis with a title and format
fig5.update_yaxes(title='Sale Price', tickprefix='$', tickformat=',')

# Customize the x-axis with a title
fig5.update_xaxes(title='Street Type')

# Hide the legend
fig5.update_layout(showlegend=False)

# Alley Prices

# Assign colors based on the alley type ('Pave' or 'Grvl')
colors_alley = np.where(alley_prices.index == 'Pave', '#FFC436', '#39A7FF')

# Create a bar chart for the average sale prices by alley type
fig6 = px.bar(
    x=alley_prices.index,  
    y=alley_prices.values,  
    title='Average Sale Price by Alley Type',  
    template='plotly_dark',  
    text=alley_prices.values,  
    color=colors_alley,  # Assign colors based on the alley type
    color_discrete_sequence=['#FFC436', '#39A7FF']  
)

# Format the text on the bars as currency values
fig6.update_traces(texttemplate='$%{text:,.0f}', textposition='outside')

# Customize the y-axis with a title and format
fig6.update_yaxes(title='Sale Price', tickprefix='$', tickformat=',')

# Customize the x-axis with a title
fig6.update_xaxes(title='Alley Type')

# Hide the legend
fig6.update_layout(showlegend=False)

# Update layout
fig5.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF')  
)

# Update layout
fig6.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF')  
)


# Show the figures
fig5.show()
fig6.show()

# %% [markdown]
# General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression

# %%
# 4. Average sale price by property shape

# Define a color palette for the charts
colors = px.colors.qualitative.Plotly

# Calculate average sale prices grouped by property shape and land contour
shape_prices = df.groupby('LotShape')['SalePrice'].mean()
contour_prices = df.groupby('LandContour')['SalePrice'].mean()

# Create a bar chart for average sale prices by property shape
fig7 = px.bar(x=shape_prices.index,
              y=shape_prices.values,
              title='Average Sale Price by Property Shape',
              template='plotly_dark', text=shape_prices.values)

fig7.update_traces(marker_color=colors, texttemplate='$%{text:,.0f}', textposition='outside')
fig7.update_yaxes(title='Sale Price', tickprefix='$', tickformat=',')
fig7.update_xaxes(title='Property Shape')
fig7.update_layout(showlegend=False)

# Create a bar chart for average sale prices by property contour
fig8 = px.bar(x=contour_prices.index,
              y=contour_prices.values,
              title='Average Sale Price by Property Contour',
              template='plotly_dark',
              text=contour_prices.values)

fig8.update_traces(marker_color=colors, texttemplate='$%{text:,.0f}', textposition='outside')
fig8.update_yaxes(title='Sale Price', tickprefix='$', tickformat=',')
fig8.update_xaxes(title='Property Contour')
fig8.update_layout(showlegend=False)

fig7.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF'))
fig8.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF'))

fig7.show()
fig8.show()

# %%
# 5. Calculate Property Age

df['PropertyAge'] = df['YrSold'] - df['YearBuilt']

# Calculate Correlation between Property Age and Sale Price by corr function
age_price_corr = df['PropertyAge'].corr(df['SalePrice'])
print(f'The Correlation between Property Age and Sale Price is: {age_price_corr}')

#visualize the relationship between Property Age and Sale Price
fig9 = px.scatter(df, 
                  x='PropertyAge',
                  y='SalePrice',
                  title='Property Age vs Sale Price',
                  color='PropertyAge',
                  color_continuous_scale=[[0, '#FFFFFF'], [1, '#39A7FF']])

fig9.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF'))

fig9.show()
# Out:
# The Correlation between Property Age and Sale Price is: -0.523350417546816

# %%
# 6. Calculate Correlation between Living Area and Sale Price

living_area_price_corr = df['GrLivArea'].corr(df['SalePrice'])
print(f'The Correlation between Living Area (above grade) and Sale Price is: {living_area_price_corr}')

fig10 = px.scatter(df, 
                   x='GrLivArea', 
                   y='SalePrice', 
                   title='Living Area (above grade) vs Sale Price', 
                   color='GrLivArea', 
                   color_continuous_scale=[[0, '#FFFFFF'], [1, '#FFC436']])

fig10.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF'))

fig10.show()
# Out:
# The Correlation between Living Area (above grade) and Sale Price is: 0.7086244776126522

# %%
# 7. Box plot of price over the years

yearly_avg_sale_price = df.groupby('YrSold')['SalePrice'].mean()

fig11 = px.box(df, x='YrSold', y='SalePrice', title='Sale Price Trends Over the Years',
               points=False, color_discrete_sequence=['#39A7FF'])

fig11.add_trace(px.line(x=yearly_avg_sale_price.index,
                        y=yearly_avg_sale_price.values
                       ).data[0])

fig11.update_traces(line=dict(color='#FFC436', width=4), selector=dict(type='scatter', mode='lines'))

# Add annotations for each year's average sale price
for year, avg_price in yearly_avg_sale_price.items():
    fig11.add_annotation(
        x=year,
        y=avg_price,
        text=f"{avg_price:,.0f}",
        font=dict(color='#FFFFFF'),
        showarrow=False,
        bgcolor='#FFC436'
    )
    

fig11.update_layout(
    plot_bgcolor='#222831',  
    paper_bgcolor='#222831',  
    font=dict(color='#FFFFFF'),
    xaxis_title='Year Sold',
    yaxis_title='Sale Price'
)

fig11.show()

# %% [markdown]
# <H1>Creating a Data Pipeline</H1><br>
# Create infrastructure that lets us make changes without breaking everything

# %%
#creating machine learning pipelines with scikit-learn

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# Define transformers for numerical and categorical columns

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
#Identify Categorical and Numerical Columns to separate categorical and numerical columns:
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

#Removes the target variable 'SalePrice' from the list of numerical columns:
numerical_columns = numerical_columns.drop('SalePrice')

#Combine Transformers using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_columns),
        ('cat', categorical_transformer, categorical_columns)
    ], remainder='passthrough')

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

#Apply the Pipeline to the Dataset :
X = df.drop('SalePrice', axis=1)
y = np.log(df['SalePrice'])  # Normalize dependent variable
X_preprocessed = pipeline.fit_transform(X)

# %% [markdown]
# # Fit and Parameter Tune models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score

# %%
#Splitting the preprocessed data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

# Creat Dictionary containing instances of three different regression models will be trained and evaluated
models = {
    'LinearRegression': LinearRegression(),
    'RandomForest': RandomForestRegressor(random_state=42),
    'XGBoost': XGBRegressor(random_state=42)
}

# Creat a dictionary specifying hyperparameter grids for each model
param_grids = {
    'LinearRegression': {},
    'RandomForest': {
        'n_estimators': [100, 200, 500],
        'max_depth': [None, 10, 30],
        'min_samples_split': [2, 5, 10],
    },
    'XGBoost': {
        'n_estimators': [100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.3],
        'max_depth': [3, 6, 10],
    }
}


# 3-fold cross-validation
cv = KFold(n_splits=3, shuffle=True, random_state=42)

# A loop through each model for training and hyperparameter tuning using GridSearchCV
grids = {}
for model_name, model in models.items():
    grids[model_name] = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=cv, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)
    grids[model_name].fit(X_train, y_train)
    best_params = grids[model_name].best_params_
    best_score = np.sqrt(-1 * grids[model_name].best_score_)
    
    print(f'Best parameters for {model_name}: {best_params}')
    print(f'Best RMSE for {model_name}: {best_score}\n')
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Best parameters for LinearRegression: {}
# Best RMSE for LinearRegression: 4752161194.279293
#
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best parameters for RandomForest: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 500}
# Best RMSE for RandomForest: 0.15332719681534118
#
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best parameters for XGBoost: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Best RMSE for XGBoost: 0.13164981859557096

# %% [markdown]
# <H1>find the best set of hyperparameters for optimal performance<H1/>

# %%
# Import the MLPRegressor class from scikit-learn
from sklearn.neural_network import MLPRegressor

X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

mlp = MLPRegressor(random_state=42, max_iter=10000, n_iter_no_change=3, learning_rate_init=0.001)

param_grid = {
    'hidden_layer_sizes': [(10,), (10, 10), (10, 10, 10), (25)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
}

grid_search_mlp = GridSearchCV(mlp, param_grid, scoring='neg_mean_squared_error', cv=3, n_jobs=-1, verbose=1)


# Fit the MLPRegressor model on the scaled training data using the grid search
grid_search_mlp.fit(X_train_scaled, y_train)

print("The Best parameters found: ", grid_search_mlp.best_params_)

best_score = np.sqrt(-1 * grid_search_mlp.best_score_)
print("Test score: ", best_score)
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# The Best parameters found:  {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# Test score:  0.22778267781613565

# %% [markdown]
# <H1>Principal Component Analysis (PCA)</H1>
# Apply Principal Component Analysis to reduce the dimensionality of the data while retaining a certain amount of variance.

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_pca_pre = pca.fit_transform(X_preprocessed)

# Calculate the cumulative explained variance for each principal component
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

n_components = np.argmax(cumulative_explained_variance >= 0.95) + 1

pca = PCA(n_components=n_components)

# Create a pipeline that includes both preprocessing and PCA
pipeline_pca = Pipeline(steps=[
    ('preprocessor', preprocessor),  # Include the preprocessor from earlier
    ('pca', pca)  # Include the PCA step in the pipeline
])

# Fit and transform the original data using the new PCA pipeline
X_pca = pipeline_pca.fit_transform(X)

# %% [markdown]
# <H1>Running the same models with new data</H1>

# %%
# Import necessary libraries and modules
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# <H3>Data Splitting</H3>

# %%
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %% [markdown]
# <H3> Model Definition & Hyperparameter Grids</H3>

# %%
# Define the models
models = {
    'LinearRegression': LinearRegression(),
    'RandomForest': RandomForestRegressor(random_state=42),
    'XGBoost': XGBRegressor(random_state=42)
}

# Define the hyperparameter grids for each model
param_grids = {
    'LinearRegression': {},
    'RandomForest': {
        'n_estimators': [100, 200, 500],
        'max_depth': [None, 10, 30],
        'min_samples_split': [2, 5, 10],
    },
    'XGBoost': {
        'n_estimators': [100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.3],
        'max_depth': [3, 6, 10],
    }
}

# %% [markdown]
# <H3>Cross-Validation Setup</H3>

# %%
cv = KFold(n_splits=3, shuffle=True, random_state=42)

# %% [markdown]
# <H3>Model Training and Tuning</H3>

# %%
grids_pca = {}
for model_name, model in models.items():
    grids_pca[model_name] = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=cv, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)
    grids_pca[model_name].fit(X_train_pca, y_train_pca)
    best_params = grids_pca[model_name].best_params_
    best_score = np.sqrt(-1 * grids_pca[model_name].best_score_)
    
    print(f'The Best parameters for {model_name}: {best_params}')
    print(f'The Best RMSE for {model_name}: {best_score}\n')
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# The Best parameters for LinearRegression: {}
# The Best RMSE for LinearRegression: 0.16275216871441847
#
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# The Best parameters for RandomForest: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 500}
# The Best RMSE for RandomForest: 0.15193024939162403
#
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# The Best parameters for XGBoost: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# The Best RMSE for XGBoost: 0.13747922633451035

# %%
from sklearn.neural_network import MLPRegressor

X_train_scaled_pca = X_train_pca.copy()
X_test_scaled_pca = X_test_pca.copy()

mlp = MLPRegressor(random_state=42, max_iter=10000, n_iter_no_change=3, learning_rate_init=0.001)

param_grid = {
    'hidden_layer_sizes': [(10,), (10, 10), (10, 10, 10), (25)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam'],
    'alpha': [0.0001, 0.001, 0.01, 0.1, 1],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
}

# Create the GridSearchCV object
grid_search_mlp_pca = GridSearchCV(mlp, param_grid, scoring='neg_mean_squared_error', cv=3, n_jobs=-1, verbose=1)

grid_search_mlp_pca.fit(X_train_scaled_pca, y_train)

# Print the best parameters found during the search
print("The Best parameters found: ", grid_search_mlp_pca.best_params_)

# Evaluate the model on the test data
best_score = np.sqrt(-1 * grid_search_mlp_pca.best_score_)
print("The Test score: ", best_score)
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# The Best parameters found:  {'activation': 'tanh', 'alpha': 1, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# The Test score:  0.21639897808281985

# %%
from sklearn.metrics import mean_squared_error

for i in grids.keys():
    # Make predictions on the test data using the trained model
    predictions = grids[i].predict(X_test)
    
    # Calculate the mean squared error between predictions and actual values (y_test)
    mse = mean_squared_error(predictions, y_test)
    
    # Print the model name and its RMSE on the test data
    print(i + ': ' + str(np.sqrt(mse)))
# Out:
# LinearRegression: 235695603.8767304
# RandomForest: 0.1468371013683763
# XGBoost: 0.14449355323399274

# %%
from sklearn.metrics import mean_squared_error

for i in grids_pca.keys():
    predictions_pca = grids_pca[i].predict(X_test_pca)
    mse_pca = mean_squared_error(predictions_pca, y_test)
    
    # Print the model name and its RMSE on the PCA-transformed test data
    print(i + ': ' + str(np.sqrt(mse_pca)))
# Out:
# LinearRegression: 0.14249036137080498
# RandomForest: 0.15303186720262363
# XGBoost: 0.1445937917252571

# %%
print( str(np.sqrt(mean_squared_error(grid_search_mlp.predict(X_test_scaled),y_test))))
# Out:
# 0.16683910272240585

# %%
print( str(np.sqrt(mean_squared_error(grid_search_mlp_pca.predict(X_test_scaled_pca),y_test))))
# Out:
# 0.1648479548978222

# %%
# Selecting specific columns of interest from the DataFrame df
var_explore = df[['Fence','Alley','MiscFeature','PoolQC','FireplaceQu','GarageCond','GarageQual','GarageFinish','GarageType','BsmtExposure','BsmtFinType2','BsmtFinType1','BsmtCond','BsmtQual','MasVnrType','Electrical','MSZoning','Utilities','Exterior1st','Exterior2nd','KitchenQual','Functional','SaleType','LotFrontage','GarageYrBlt','MasVnrArea','BsmtFullBath','BsmtHalfBath','GarageCars','GarageArea','TotalBsmtSF']]

# Creating a scrollable table for better exploration
display(HTML(create_scrollable_table(var_explore, 'var_explore', 'List of Variables to Explore for Feature Engineering')))
# Out:
# <h3>List of Variables to Explore for Feature Engineering</h3><dive id="{table_id}" style="hight:300px ; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Fence</th>
#       <th>Alley</th>
#       <th>MiscFeature</th>
#       <th>PoolQC</th>
#       <th>FireplaceQu</th>
#       <th>GarageCond</th>
#       <th>GarageQual</th>
#       <th>GarageFinish</th>
#       <th>GarageType</th>
#       <th>BsmtExposure</th>
#       <th>BsmtFinType2</th>
#       <th>BsmtFinType1</th>
#       <th>BsmtCond</th>
#       <th>BsmtQual</th>
#       <th>MasVnrType</th>
#       <th>Electrical</th>
#       <th>MSZoning</th>
#       <th>Utilities</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>KitchenQual</th>
#       <th>Functional</th>
#       <th>SaleType</th>
#       <th>LotFrontage</th>
#       <th>GarageYrBlt</th>
#       <th>MasVnrArea</th>
#       <th>BsmtFullBath</th>
# ...
